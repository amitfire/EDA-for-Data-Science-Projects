# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DATA MA - DATA.csv')

# %%
df
# Out:
#          Dates Company Name  NUM_OF_CSR_SUSTAIN_CMTE_MTGS  \
# 0   31-03-2022         MSIL                           2.0
# 1   31-03-2021         MSIL                           2.0
# 2   31-03-2020         MSIL                           1.0
# 3   31-03-2019         MSIL                           3.0
# 4   31-03-2018         MSIL                           2.0
# 5   31-03-2017         MSIL                           2.0
# 6   31-03-2016         MSIL                           NaN
# 7   31-03-2015         MSIL                           NaN
# 8   31-03-2014         MSIL                           NaN
# 9   31-03-2013         MSIL                           NaN
# 10  31-03-2012         MSIL                           NaN
# 11  31-03-2022         TATA                           2.0
# 12  31-03-2021         TATA                           2.0
# 13  31-03-2020         TATA                           4.0
# 14  31-03-2019         TATA                           2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 42 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Dates                            55 non-null     object
#  1   Company Name                     55 non-null     object
#  2   NUM_OF_CSR_SUSTAIN_CMTE_MTGS     34 non-null     float64
#  3   SIZE_OF_CSR_SUSTAIN_COMMTTEE     35 non-null     float64
#  4   TOBIN_Q_RATIO                    53 non-null     float64
#  5   RETURN_ON_ASSET                  51 non-null     float64
#  6   RETURN_COM_EQY                   51 non-null     float64
#  7   ARDR_LIQUIDITY_RATIO             0 non-null      float64
#  8   ESG_DISCLOSURE_SCORE             51 non-null     float64
#  9   GOVNCE_DISCLOSURE_SCORE          51 non-null     float64
#  10  ENVIRON_DISCLOSURE_SCORE         51 non-null     float64
#  11  SOCIAL_DISCLOSURE_SCORE          51 non-null     float64
# ...

# %%
df['Dates']= pd.to_datetime(df['Dates'])

# %%
import datetime as dt
df['Year'] = df['Dates'].dt.year

# %%
df= df.drop(['Dates'],1)

# %%
gri_data = df.groupby(['GRI_COMPLIANCE','Year']).agg({'RETURN_ON_ASSET':np.mean ,'ESG_SCORE':np.mean ,'TOBIN_Q_RATIO':np.mean ,'NET_INCOME':np.mean,'EBITDA':np.mean}).reset_index()

# %%
gri_data
# Out:
#     GRI_COMPLIANCE  Year  RETURN_ON_ASSET  ESG_SCORE  TOBIN_Q_RATIO  \
# 0              0.0  2013              NaN        NaN       3.674400
# 1              0.0  2014        21.278500        NaN       4.932400
# 2              0.0  2015        12.946200   1.345000       3.407050
# 3              0.0  2016        14.944900   1.445000       3.253750
# 4              0.0  2017        14.392750   1.585000       3.208000
# 5              0.0  2018         3.402500   1.720000       2.011900
# 6              0.0  2019         3.822400   1.870000       2.246100
# 7              0.0  2020         3.647500   1.800000       1.612000
# 8              0.0  2021         2.631900   2.070000       2.591400
# 9              0.0  2022         3.660800   2.070000       2.855300
# 10             1.0  2012         8.140600        NaN       1.590767
# 11             1.0  2013         7.292267        NaN       1.467300
# 12             1.0  2014         7.501967        NaN       1.628733
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 8))

fig.suptitle('Distibution of average of Financial Parameters of companies which are GRI compiant Vs which are not over time')
sns.set_style("whitegrid")
palette = sns.color_palette("mako_r", 6)

sns.lineplot(ax=axes[0, 0], data=gri_data, x='Year', y='TOBIN_Q_RATIO', hue='GRI_COMPLIANCE', palette = "mako_r")
sns.lineplot(ax=axes[0, 1], data=gri_data, x='Year', y='EBITDA',hue='GRI_COMPLIANCE',palette = "mako_r")
sns.lineplot(ax=axes[1, 0], data=gri_data, x='Year', y='NET_INCOME',hue='GRI_COMPLIANCE',palette = "mako_r")
sns.lineplot(ax=axes[1, 1], data=gri_data, x='Year', y='RETURN_ON_ASSET',hue='GRI_COMPLIANCE',palette = "mako_r")

plt.show()

# %%
df.describe()
# Out:
#        NUM_OF_CSR_SUSTAIN_CMTE_MTGS  SIZE_OF_CSR_SUSTAIN_COMMTTEE  \
# count                     34.000000                     35.000000
# mean                       2.794118                      3.628571
# std                        0.977920                      0.731063
# min                        1.000000                      3.000000
# 25%                        2.000000                      3.000000
# 50%                        3.000000                      3.000000
# 75%                        3.000000                      4.000000
# max                        5.000000                      5.000000
#
#        TOBIN_Q_RATIO  RETURN_ON_ASSET  RETURN_COM_EQY  ARDR_LIQUIDITY_RATIO  \
# count      53.000000        51.000000       51.000000                   0.0
# mean        2.216689         7.636012       16.532867                   NaN
# std         1.215968         7.666979       15.780828                   NaN
# ...

# %%
df.sample(10)
# Out:
#    Company Name  NUM_OF_CSR_SUSTAIN_CMTE_MTGS  SIZE_OF_CSR_SUSTAIN_COMMTTEE  \
# 4          MSIL                           2.0                           3.0
# 8          MSIL                           NaN                           NaN
# 39         HMCL                           NaN                           NaN
# 52        BAJAJ                           NaN                           NaN
# 22     MAHINDRA                           3.0                           5.0
# 50        BAJAJ                           5.0                           3.0
# 2          MSIL                           1.0                           3.0
# 27     MAHINDRA                           3.0                           5.0
# 11         TATA                           2.0                           4.0
# 34         HMCL                           2.0                           4.0
#
#     TOBIN_Q_RATIO  RETURN_ON_ASSET  RETURN_COM_EQY  ARDR_LIQUIDITY_RATIO  \
# ...

# %%
sns.set_style('whitegrid')
palette = sns.color_palette("mako_r", 6)
plt.figure(figsize = (15,5))
ax = sns.barplot(df['Year'],df['CSR_EXPENSE'],hue=df['Company Name'],palette = palette )
plt.legend(loc='upper left')
plt.title('This chart shows us the distribution of CSR expense by different companies over the years')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 42 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Company Name                     55 non-null     object
#  1   NUM_OF_CSR_SUSTAIN_CMTE_MTGS     34 non-null     float64
#  2   SIZE_OF_CSR_SUSTAIN_COMMTTEE     35 non-null     float64
#  3   TOBIN_Q_RATIO                    53 non-null     float64
#  4   RETURN_ON_ASSET                  51 non-null     float64
#  5   RETURN_COM_EQY                   51 non-null     float64
#  6   ARDR_LIQUIDITY_RATIO             0 non-null      float64
#  7   ESG_DISCLOSURE_SCORE             51 non-null     float64
#  8   GOVNCE_DISCLOSURE_SCORE          51 non-null     float64
#  9   ENVIRON_DISCLOSURE_SCORE         51 non-null     float64
#  10  SOCIAL_DISCLOSURE_SCORE          51 non-null     float64
#  11  CSR_SUSTAINABILITY_COMMITTEE     51 non-null     float64
# ...

# %%
sns.set_style('whitegrid')
# palette = sns.color_palette("mako_r",8)
plt.figure(figsize = (15,5))
ax = sns.lineplot(df['Year'],df['ESG_SCORE'],hue=df['Company Name'],palette = "mako_r" )
# ax = sns.barplot(df['Year'],df['CSR_EXPENSE'],hue=df['Company Name'],palette = palette )

plt.legend(loc='upper left')
plt.title('This chart shows us the distribution of ESG Score by different companies over the years')
plt.show()
# sns.lineplot(df['Year'],df['ESG_SCORE'],hue=df['Company Name'])

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

fig.suptitle('Correlation of ESG score with Financial Parameters')
sns.set_style("ticks")

ax1 = sns.regplot(ax=axes[0, 0], data=df, x='TOBIN_Q_RATIO', y='GOVERNANCE_SCORE',color = "green")
sns.regplot(ax=axes[0, 1], data=df, x='RETURN_ON_ASSET', y='GOVERNANCE_SCORE',color = "green")
sns.regplot(ax=axes[0, 2], data=df, x='SALES_GROWTH', y='GOVERNANCE_SCORE',color = "green")
sns.regplot(ax=axes[1, 0], data=df, x='ALTMAN_Z_SCORE', y='GOVERNANCE_SCORE',color = "green")
sns.regplot(ax=axes[1, 1], data=df, x='TOT_DEBT_TO_TOT_EQY', y='GOVERNANCE_SCORE',color = "green")
sns.regplot(ax=axes[1, 2], data=df, x='RETURN_COM_EQY', y='GOVERNANCE_SCORE',color = "green")
ax1.set(xlabel=None)
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

fig.suptitle('Correlation of % of Women on Board with Financial Parameters')
sns.set_style("ticks")

sns.regplot(ax=axes[0, 0], data=df, x='PCT_WOMEN_ON_BOARD', y='TOBIN_Q_RATIO',color = "green")
sns.regplot(ax=axes[0, 1], data=df, x='RETURN_ON_ASSET', y='PCT_WOMEN_ON_BOARD',color = "green")
sns.regplot(ax=axes[0, 2], data=df, x='SALES_GROWTH', y='PCT_WOMEN_ON_BOARD',color = "green")
sns.regplot(ax=axes[1, 0], data=df, x='ALTMAN_Z_SCORE', y='PCT_WOMEN_ON_BOARD',color = "green")
sns.regplot(ax=axes[1, 1], data=df, x='TOT_DEBT_TO_TOT_EQY', y='PCT_WOMEN_ON_BOARD',color = "green")
sns.regplot(ax=axes[1, 2], data=df, x='RETURN_COM_EQY', y='PCT_WOMEN_ON_BOARD',color = "green")
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

fig.suptitle('Correlation of  SOCIAL_PILLAR_DISCLOSURE score with Financial Parameters')
sns.set_style("ticks")

sns.regplot(ax=axes[0, 0], data=df, x='TOBIN_Q_RATIO', y='SOCIAL_PILLAR_DISCLOSURE',color = "green")
sns.regplot(ax=axes[0, 1], data=df, x='RETURN_ON_ASSET', y='SOCIAL_PILLAR_DISCLOSURE',color = "green")
sns.regplot(ax=axes[0, 2], data=df, x='SALES_GROWTH', y='SOCIAL_PILLAR_DISCLOSURE',color = "green")
sns.regplot(ax=axes[1, 0], data=df, x='ALTMAN_Z_SCORE', y='SOCIAL_PILLAR_DISCLOSURE',color = "green")
sns.regplot(ax=axes[1, 1], data=df, x='TOT_DEBT_TO_TOT_EQY', y='SOCIAL_PILLAR_DISCLOSURE',color = "green")
sns.regplot(ax=axes[1, 2], data=df, x='RETURN_COM_EQY', y='SOCIAL_PILLAR_DISCLOSURE',color = "green")
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

fig.suptitle('Correlation of COMMUNITY SPENDING by companies with Financial Parameters')
sns.set_style("ticks")

sns.regplot(ax=axes[0, 0], data=df, x='TOBIN_Q_RATIO', y='COMMUNITY_SPENDING',color = "green")
sns.regplot(ax=axes[0, 1], data=df, x='RETURN_ON_ASSET', y='COMMUNITY_SPENDING',color = "green")
sns.regplot(ax=axes[0, 2], data=df, x='SALES_GROWTH', y='COMMUNITY_SPENDING',color = "green")
sns.regplot(ax=axes[1, 0], data=df, x='ALTMAN_Z_SCORE', y='COMMUNITY_SPENDING',color = "green")
sns.regplot(ax=axes[1, 1], data=df, x='TOT_DEBT_TO_TOT_EQY', y='COMMUNITY_SPENDING',color = "green")
sns.regplot(ax=axes[1, 2], data=df, x='RETURN_COM_EQY', y='COMMUNITY_SPENDING',color = "green")
plt.show()

# %%
columns = ['Company Name', 'NUM_OF_CSR_SUSTAIN_CMTE_MTGS',
       'SIZE_OF_CSR_SUSTAIN_COMMTTEE', 'TOBIN_Q_RATIO', 'RETURN_ON_ASSET',
       'RETURN_COM_EQY',  'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 'SOCIAL_SCORE', 'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 'PCT_DISABLED_IN_WORKFORCE',
        'SALES_GROWTH', 'ALTMAN_Z_SCORE', 'CUR_RATIO',
       'TOT_DEBT_TO_TOT_EQY', 'NET_INCOME', 'GRI_COMPLIANCE', 'CUR_RATIO.1',
       'EBITDA', 'CSR_BUDGET', 'CSR_EXPENSE', 'Year']

# %%
req_df = df[columns]

# %%
req_df.describe()
# Out:
#        NUM_OF_CSR_SUSTAIN_CMTE_MTGS  SIZE_OF_CSR_SUSTAIN_COMMTTEE  \
# count                     34.000000                     35.000000
# mean                       2.794118                      3.628571
# std                        0.977920                      0.731063
# min                        1.000000                      3.000000
# 25%                        2.000000                      3.000000
# 50%                        3.000000                      3.000000
# 75%                        3.000000                      4.000000
# max                        5.000000                      5.000000
#
#        TOBIN_Q_RATIO  RETURN_ON_ASSET  RETURN_COM_EQY  ESG_DISCLOSURE_SCORE  \
# count      53.000000        51.000000       51.000000             51.000000
# mean        2.216689         7.636012       16.532867             49.871494
# std         1.215968         7.666979       15.780828             10.204427
# ...

# %%
roe = ['Company Name',
        'RETURN_COM_EQY', 
       'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 
       'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 
       'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 
       'SOCIAL_SCORE', 
       'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 
       'PCT_DISABLED_IN_WORKFORCE','CSR_EXPENSE']
,
tobin = ['Company Name',
        'TOBIN_Q_RATIO', 
       'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 
       'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 
       'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 
       'SOCIAL_SCORE', 
       'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 
       'PCT_DISABLED_IN_WORKFORCE','CSR_EXPENSE']
,
roa = ['Company Name',
        'RETURN_ON_ASSET', 
       'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 
       'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 
       'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 
       'SOCIAL_SCORE', 
       'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 
       'PCT_DISABLED_IN_WORKFORCE','CSR_EXPENSE']
,
ebitda = ['Company Name',
        'EBITDA', 
       'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 
       'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 
       'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 
       'SOCIAL_SCORE', 
       'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 
       'PCT_DISABLED_IN_WORKFORCE','CSR_EXPENSE']
,
net_income = ['Company Name',
        'NET_INCOME', 
       'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 
       'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 
       'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 
       'SOCIAL_SCORE', 
       'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 
       'PCT_DISABLED_IN_WORKFORCE','CSR_EXPENSE']
,

sales_growth = ['Company Name',
        'SALES_GROWTH', 
       'ESG_DISCLOSURE_SCORE',
       'GOVNCE_DISCLOSURE_SCORE', 
       'ENVIRON_DISCLOSURE_SCORE',
       'SOCIAL_DISCLOSURE_SCORE', 
       'CSR_SUSTAINABILITY_COMMITTEE',
        'PCT_WOMEN_ON_BOARD', 
       'GOVERNANCE_SCORE', 
       'SOCIAL_SCORE', 
       'SOCIAL_PILLAR_DISCLOSURE',
       'COMMUNITY_SPENDING', 
       'NUMBER_EMPLOYEES_CSR', 
       'PCT_DISABLED_IN_WORKFORCE','CSR_EXPENSE']

# %%
roe_df = df[roe]
roa_df = df[roa]
tobin_df = df[tobin]
ebitda_df = df[ebitda]
net_income_df = df[net_income]
sales_growth_df = df[sales_growth]

# %%
data_list=[roa_df,roe_df,tobin_df,ebitda_df,net_income_df,sales_growth_df]

# %%
companies = list(roe_df['Company Name'].unique())
companies
# Out:
# ['MSIL', 'TATA', 'MAHINDRA', 'HMCL', 'BAJAJ']

# %%
#overall
correlation = pd.DataFrame(roe_df.corr().reset_index().loc[0].reset_index()) \
.merge(pd.DataFrame(roa_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('v','r')) \
.merge(pd.DataFrame(tobin_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('t','s')) \
.merge(pd.DataFrame(ebitda_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('e','d')) \
.merge(pd.DataFrame(net_income_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('n','k')) \
.merge(pd.DataFrame(sales_growth_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('q','p'))
correlation = correlation.rename(columns = { 'index':'Parameters','0v':'RETURN_COM_EQY' , '0r':'RETURN_ON_ASSET','0e':'TOBIN_Q_RATIO','0d':'EBITDA','0q':'NET_INCOME','0p':'SALES_GROWTH'}).drop([0],axis=0)
correlation.head()
# Out:
#                      Parameters RETURN_COM_EQY RETURN_ON_ASSET TOBIN_Q_RATIO  \
# 1          ESG_DISCLOSURE_SCORE     -0.0367976        0.121906     -0.101554
# 2       GOVNCE_DISCLOSURE_SCORE      -0.258136       -0.297557     -0.253547
# 3      ENVIRON_DISCLOSURE_SCORE     -0.0153712        0.218448     0.0168493
# 4       SOCIAL_DISCLOSURE_SCORE        0.15716        0.138366    -0.0989569
# 5  CSR_SUSTAINABILITY_COMMITTEE      -0.237354         -0.1206    -0.0326341
#
#        EBITDA NET_INCOME SALES_GROWTH
# 1 -0.00722867    0.22083    -0.396956
# 2    0.486045  -0.180755   -0.0414218
# 3   -0.101846   0.207099    -0.399678
# 4    -0.22799   0.341215    -0.218164
# 5     0.23746 -0.0515771    -0.260035

# %%
#MISL
correlation_MISL = pd.DataFrame(roe_df[roe_df['Company Name']=='MSIL'].corr().reset_index().loc[0].reset_index()) \
.merge(pd.DataFrame(roa_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('v','r')) \
.merge(pd.DataFrame(tobin_df[tobin_df['Company Name']=='MSIL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('t','s')) \
.merge(pd.DataFrame(ebitda_df[ebitda_df['Company Name']=='MSIL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('e','d')) \
.merge(pd.DataFrame(net_income_df[net_income_df['Company Name']=='MSIL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('n','k')) \
.merge(pd.DataFrame(sales_growth_df[sales_growth_df['Company Name']=='MSIL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('q','p'))
correlation_MISL = correlation_MISL.rename(columns = { 'index':'Parameters','0v':'RETURN_COM_EQY' , '0r':'RETURN_ON_ASSET','0e':'TOBIN_Q_RATIO','0d':'EBITDA','0q':'NET_INCOME','0p':'SALES_GROWTH'}).drop([0],axis=0)
correlation_MISL.head()
# Out:
#                      Parameters RETURN_COM_EQY RETURN_ON_ASSET TOBIN_Q_RATIO  \
# 1          ESG_DISCLOSURE_SCORE      -0.255569        0.121906      0.351731
# 2       GOVNCE_DISCLOSURE_SCORE      -0.238445       -0.297557      0.369998
# 3      ENVIRON_DISCLOSURE_SCORE      0.0724665        0.218448      0.613752
# 4       SOCIAL_DISCLOSURE_SCORE      -0.459742        0.138366     -0.734261
# 5  CSR_SUSTAINABILITY_COMMITTEE       0.212017         -0.1206      0.630552
#
#      EBITDA NET_INCOME SALES_GROWTH
# 1  0.327925   0.499529   -0.0862248
# 2  0.301669   0.449805    -0.063555
# 3   0.63647   0.773341   -0.0195867
# 4 -0.723852  -0.729911    -0.105437
# 5  0.617854   0.630705   -0.0458249

# %%
#TATA
correlation_TATA = pd.DataFrame(roe_df[roe_df['Company Name']=='TATA'].corr().reset_index().loc[0].reset_index()) \
.merge(pd.DataFrame(roa_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('v','r')) \
.merge(pd.DataFrame(tobin_df[tobin_df['Company Name']=='TATA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('t','s')) \
.merge(pd.DataFrame(ebitda_df[ebitda_df['Company Name']=='TATA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('e','d')) \
.merge(pd.DataFrame(net_income_df[net_income_df['Company Name']=='TATA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('n','k')) \
.merge(pd.DataFrame(sales_growth_df[sales_growth_df['Company Name']=='TATA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('q','p'))
correlation_TATA = correlation_TATA.rename(columns = { 'index':'Parameters','0v':'RETURN_COM_EQY' , '0r':'RETURN_ON_ASSET','0e':'TOBIN_Q_RATIO','0d':'EBITDA','0q':'NET_INCOME','0p':'SALES_GROWTH'}).drop([0],axis=0)
correlation_TATA.head()
# Out:
#                      Parameters RETURN_COM_EQY RETURN_ON_ASSET TOBIN_Q_RATIO  \
# 1          ESG_DISCLOSURE_SCORE       0.731149        0.121906      0.174271
# 2       GOVNCE_DISCLOSURE_SCORE      -0.661634       -0.297557     -0.305483
# 3      ENVIRON_DISCLOSURE_SCORE       0.714786        0.218448      0.151123
# 4       SOCIAL_DISCLOSURE_SCORE       0.736848        0.138366      0.257775
# 5  CSR_SUSTAINABILITY_COMMITTEE      -0.549335         -0.1206     -0.267006
#
#      EBITDA NET_INCOME SALES_GROWTH
# 1 -0.402159   0.583389     0.622282
# 2   0.32143  -0.448849    -0.811377
# 3 -0.339169   0.590223     0.580776
# 4 -0.428564    0.53643     0.761379
# 5  0.433227  -0.273683    -0.666913

# %%
#MAHINDRA
correlation_MAHINDRA = pd.DataFrame(roe_df[roe_df['Company Name']=='MAHINDRA'].corr().reset_index().loc[0].reset_index()) \
.merge(pd.DataFrame(roa_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('v','r')) \
.merge(pd.DataFrame(tobin_df[tobin_df['Company Name']=='MAHINDRA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('t','s')) \
.merge(pd.DataFrame(ebitda_df[ebitda_df['Company Name']=='MAHINDRA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('e','d')) \
.merge(pd.DataFrame(net_income_df[net_income_df['Company Name']=='MAHINDRA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('n','k')) \
.merge(pd.DataFrame(sales_growth_df[sales_growth_df['Company Name']=='MAHINDRA'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('q','p'))
correlation_MAHINDRA = correlation_MAHINDRA.rename(columns = { 'index':'Parameters','0v':'RETURN_COM_EQY' , '0r':'RETURN_ON_ASSET','0e':'TOBIN_Q_RATIO','0d':'EBITDA','0q':'NET_INCOME','0p':'SALES_GROWTH'}).drop([0],axis=0)
correlation_MAHINDRA.head()
# Out:
#                      Parameters RETURN_COM_EQY RETURN_ON_ASSET TOBIN_Q_RATIO  \
# 1          ESG_DISCLOSURE_SCORE      -0.465022        0.121906     -0.375517
# 2       GOVNCE_DISCLOSURE_SCORE      -0.352073       -0.297557     -0.485909
# 3      ENVIRON_DISCLOSURE_SCORE      -0.156037        0.218448    -0.0412908
# 4       SOCIAL_DISCLOSURE_SCORE      -0.505255        0.138366     -0.319933
# 5  CSR_SUSTAINABILITY_COMMITTEE      -0.471688         -0.1206     -0.283748
#
#      EBITDA NET_INCOME SALES_GROWTH
# 1  0.616881   0.176633    -0.470798
# 2  0.669503  -0.179022     0.125298
# 3  0.267696   0.395132    -0.391122
# 4  0.404043  0.0792295    -0.684527
# 5  0.354252  0.0751916    -0.613992

# %%
#HMCL
correlation_HMCL = pd.DataFrame(roe_df[roe_df['Company Name']=='HMCL'].corr().reset_index().loc[0].reset_index()) \
.merge(pd.DataFrame(roa_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('v','r')) \
.merge(pd.DataFrame(tobin_df[tobin_df['Company Name']=='HMCL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('t','s')) \
.merge(pd.DataFrame(ebitda_df[ebitda_df['Company Name']=='HMCL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('e','d')) \
.merge(pd.DataFrame(net_income_df[net_income_df['Company Name']=='HMCL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('n','k')) \
.merge(pd.DataFrame(sales_growth_df[sales_growth_df['Company Name']=='HMCL'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('q','p'))
correlation_HMCL = correlation_HMCL.rename(columns = { 'index':'Parameters','0v':'RETURN_COM_EQY' , '0r':'RETURN_ON_ASSET','0e':'TOBIN_Q_RATIO','0d':'EBITDA','0q':'NET_INCOME','0p':'SALES_GROWTH'}).drop([0],axis=0)
correlation_HMCL.head()
# Out:
#                      Parameters RETURN_COM_EQY RETURN_ON_ASSET TOBIN_Q_RATIO  \
# 1          ESG_DISCLOSURE_SCORE      -0.875382        0.121906     -0.676148
# 2       GOVNCE_DISCLOSURE_SCORE      -0.833301       -0.297557     -0.476684
# 3      ENVIRON_DISCLOSURE_SCORE      -0.864704        0.218448     -0.737793
# 4       SOCIAL_DISCLOSURE_SCORE      -0.768934        0.138366     -0.529269
# 5  CSR_SUSTAINABILITY_COMMITTEE      -0.344491         -0.1206     -0.228029
#
#      EBITDA NET_INCOME SALES_GROWTH
# 1  0.472226   0.559039    -0.321993
# 2   0.50826   0.546246    -0.238076
# 3  0.444124   0.522724    -0.330115
# 4      0.45   0.575541    -0.280111
# 5  0.536613   0.659916     -0.18226

# %%
#BAJAJ
correlation_BAJAJ= pd.DataFrame(roe_df[roe_df['Company Name']=='BAJAJ'].corr().reset_index().loc[0].reset_index()) \
.merge(pd.DataFrame(roa_df.corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('v','r')) \
.merge(pd.DataFrame(tobin_df[tobin_df['Company Name']=='BAJAJ'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('t','s')) \
.merge(pd.DataFrame(ebitda_df[ebitda_df['Company Name']=='BAJAJ'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('e','d')) \
.merge(pd.DataFrame(net_income_df[net_income_df['Company Name']=='BAJAJ'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('n','k')) \
.merge(pd.DataFrame(sales_growth_df[sales_growth_df['Company Name']=='BAJAJ'].corr().reset_index().loc[0]).reset_index(),how='inner',on = 'index',suffixes = ('q','p'))
correlation_BAJAJ = correlation_BAJAJ.rename(columns = { 'index':'Parameters','0v':'RETURN_COM_EQY' , '0r':'RETURN_ON_ASSET','0e':'TOBIN_Q_RATIO','0d':'EBITDA','0q':'NET_INCOME','0p':'SALES_GROWTH'}).drop([0],axis=0)
correlation_BAJAJ.head()
# Out:
#                      Parameters RETURN_COM_EQY RETURN_ON_ASSET TOBIN_Q_RATIO  \
# 1          ESG_DISCLOSURE_SCORE      -0.586018        0.121906       0.78683
# 2       GOVNCE_DISCLOSURE_SCORE      -0.111001       -0.297557      0.354251
# 3      ENVIRON_DISCLOSURE_SCORE       -0.86172        0.218448      0.895843
# 4       SOCIAL_DISCLOSURE_SCORE      -0.675893        0.138366      0.846857
# 5  CSR_SUSTAINABILITY_COMMITTEE            NaN         -0.1206           NaN
#
#      EBITDA NET_INCOME SALES_GROWTH
# 1  0.879358    0.82877    -0.506037
# 2  0.492389   0.410176   -0.0649949
# 3  0.785609   0.776254    -0.826262
# 4  0.938844    0.90813    -0.583102
# 5       NaN        NaN          NaN

# %%
plt.figure(figsize = (15,12))
sns.heatmap(req_df.drop(['Year','CSR_EXPENSE','CSR_BUDGET'],1).corr(),annot=True , center=0,cbar=False,linewidths = 2,
linecolor = "green",
            cmap="Greens")
plt.show()

# %%
req_df.head()
# Out:
#   Company Name  NUM_OF_CSR_SUSTAIN_CMTE_MTGS  SIZE_OF_CSR_SUSTAIN_COMMTTEE  \
# 0         MSIL                           2.0                           3.0
# 1         MSIL                           2.0                           3.0
# 2         MSIL                           1.0                           3.0
# 3         MSIL                           3.0                           3.0
# 4         MSIL                           2.0                           3.0
#
#    TOBIN_Q_RATIO  RETURN_ON_ASSET  RETURN_COM_EQY  ESG_DISCLOSURE_SCORE  \
# 0         3.3184           5.3132          7.1953               64.6514
# 1         3.1674           6.5022          8.6134               64.6514
# 2         2.2593           8.8968         11.7631               62.1366
# 3         3.4148          12.3157         17.0641               57.9519
# 4         4.7365          14.0452         19.7904               55.3767
#
#    GOVNCE_DISCLOSURE_SCORE  ENVIRON_DISCLOSURE_SCORE  SOCIAL_DISCLOSURE_SCORE  \
# ...

# %%
data_list=[roa_df,roe_df,tobin_df,ebitda_df,net_income_df,sales_growth_df]

# %%
   
roa_df = roa_df.fillna(0)
X1 = roa_df.drop(['RETURN_ON_ASSET','Company Name'], axis=1)
y1= roa_df['RETURN_ON_ASSET']
from sklearn.linear_model import LinearRegression
lin_reg_1 = LinearRegression()
lin_reg_1.fit(X1,y1)
print('---------------------------------------')
print(f'Coefficients: {lin_reg_1.coef_}')
print(f'Intercept: {lin_reg_1.intercept_}')
print(f'R^2 score: {lin_reg_1.score(X1, y1)}')
print('---------------------------------------')

  
roe_df = roe_df.fillna(0)
X2 = roe_df.drop(['RETURN_COM_EQY','Company Name'], axis=1)
y2= roe_df['RETURN_COM_EQY']
from sklearn.linear_model import LinearRegression
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X2,y2)
print('---------------------------------------')
print(f'Coefficients: {lin_reg_2.coef_}')
print(f'Intercept: {lin_reg_2.intercept_}')
print(f'R^2 score: {lin_reg_2.score(X2, y2)}')
print('---------------------------------------')

  
tobin_df = tobin_df.fillna(0)
X3 = tobin_df.drop(['TOBIN_Q_RATIO','Company Name'], axis=1)
y3= tobin_df['TOBIN_Q_RATIO']
from sklearn.linear_model import LinearRegression
lin_reg_3 = LinearRegression()
lin_reg_3.fit(X3,y3)
print('---------------------------------------')
print(f'Coefficients: {lin_reg_3.coef_}')
print(f'Intercept: {lin_reg_3.intercept_}')
print(f'R^2 score: {lin_reg_3.score(X3, y3)}')
print('---------------------------------------')

  
ebitda_df = ebitda_df.fillna(0)
X4 = ebitda_df.drop(['EBITDA','Company Name'], axis=1)
y4= ebitda_df['EBITDA']
from sklearn.linear_model import LinearRegression
lin_reg_4 = LinearRegression()
lin_reg_4.fit(X4,y4)
print('---------------------------------------')
print(f'Coefficients: {lin_reg_4.coef_}')
print(f'Intercept: {lin_reg_4.intercept_}')
print(f'R^2 score: {lin_reg_4.score(X4, y4)}')
print('---------------------------------------')

  
net_income_df = net_income_df.fillna(0)
X5 = net_income_df.drop(['NET_INCOME','Company Name'], axis=1)
y5= net_income_df['NET_INCOME']
from sklearn.linear_model import LinearRegression
lin_reg_5 = LinearRegression()
lin_reg_5.fit(X5,y5)
print('---------------------------------------')
print(f'Coefficients: {lin_reg_5.coef_}')
print(f'Intercept: {lin_reg_5.intercept_}')
print(f'R^2 score: {lin_reg_5.score(X5, y5)}')
print('---------------------------------------')


sales_growth_df = sales_growth_df.fillna(0)
X6 = sales_growth_df.drop(['SALES_GROWTH','Company Name'], axis=1)
y6= sales_growth_df['SALES_GROWTH']
from sklearn.linear_model import LinearRegression
lin_reg_6 = LinearRegression()
lin_reg_6.fit(X6,y6)
print('---------------------------------------')
print(f'Coefficients: {lin_reg_6.coef_}')
print(f'Intercept: {lin_reg_6.intercept_}')
print(f'R^2 score: {lin_reg_6.score(X6, y6)}')
print('---------------------------------------')
# Out:
# ---------------------------------------
# Coefficients: [ 2.69593754e+04 -9.00906869e+03 -8.97912197e+03 -8.97099881e+03
#   3.33308959e-01 -5.79476126e-01  1.99366514e+00 -1.42194938e-01
#  -3.06111140e+01  1.53567248e-03 -8.97660742e-07  8.15015617e+00
#  -6.49647842e-02]
# Intercept: 3.2703776483614444
# R^2 score: 0.41757845826275064
# ---------------------------------------
# ---------------------------------------
# Coefficients: [-1.31262951e+04  4.38656122e+03  4.37204872e+03  4.36815198e+03
#   4.88175197e+00 -1.57489874e+00  2.76685577e+00 -4.21649533e+00
#  -7.20752587e-01 -1.96140715e-03 -1.71854834e-06  1.27760515e+01
#  -1.12386241e-01]
# Intercept: 6.56417299403274
# R^2 score: 0.5546971451525787
# ---------------------------------------
# ---------------------------------------
# Coefficients: [ 7.70702282e+03 -2.57545726e+03 -2.56693111e+03 -2.56461777e+03
#  -1.53073124e-01 -6.89673706e-02  2.61884413e-01 -5.81684543e-02
# ...

# %%
import warnings 
warnings.filterwarnings('ignore')
import statsmodels.api as sm

X_constant1 = sm.add_constant(X1)
lin_reg_1 = sm.OLS(y1,X_constant1).fit()
lin_reg_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        RETURN_ON_ASSET   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     2.261
# Date:                Fri, 10 Feb 2023   Prob (F-statistic):             0.0236
# Time:                        10:40:48   Log-Likelihood:                -174.54
# No. Observations:                  55   AIC:                             377.1
# Df Residuals:                      41   BIC:                             405.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
X_constant2 = sm.add_constant(X2)
lin_reg_2 = sm.OLS(y2,X_constant2).fit()
lin_reg_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         RETURN_COM_EQY   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.414
# Method:                 Least Squares   F-statistic:                     3.929
# Date:                Fri, 10 Feb 2023   Prob (F-statistic):           0.000385
# Time:                        10:40:48   Log-Likelihood:                -207.06
# No. Observations:                  55   AIC:                             442.1
# Df Residuals:                      41   BIC:                             470.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
X_constant3 = sm.add_constant(X3)
lin_reg_3 = sm.OLS(y3,X_constant3).fit()
lin_reg_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          TOBIN_Q_RATIO   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.9461
# Date:                Fri, 10 Feb 2023   Prob (F-statistic):              0.517
# Time:                        10:40:48   Log-Likelihood:                -83.234
# No. Observations:                  55   AIC:                             194.5
# Df Residuals:                      41   BIC:                             222.6
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
X_constant4 = sm.add_constant(X4)
lin_reg_4 = sm.OLS(y4,X_constant4).fit()
lin_reg_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 EBITDA   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     4.927
# Date:                Fri, 10 Feb 2023   Prob (F-statistic):           4.15e-05
# Time:                        10:40:48   Log-Likelihood:                -685.29
# No. Observations:                  55   AIC:                             1399.
# Df Residuals:                      41   BIC:                             1427.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
X_constant5 = sm.add_constant(X5)
lin_reg_5 = sm.OLS(y5,X_constant5).fit()
lin_reg_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             NET_INCOME   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     3.120
# Date:                Fri, 10 Feb 2023   Prob (F-statistic):            0.00269
# Time:                        10:40:48   Log-Likelihood:                -670.12
# No. Observations:                  55   AIC:                             1368.
# Df Residuals:                      41   BIC:                             1396.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
X_constant6 = sm.add_constant(X6)
lin_reg_6 = sm.OLS(y6,X_constant6).fit()
lin_reg_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           SALES_GROWTH   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     3.436
# Date:                Fri, 10 Feb 2023   Prob (F-statistic):            0.00124
# Time:                        10:40:48   Log-Likelihood:                -212.68
# No. Observations:                  55   AIC:                             453.4
# Df Residuals:                      41   BIC:                             481.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### H0  : B2  = 0       ( variable X has no influence on Y)
# ### Ha  : B2  ≠ 0      (X has significant impact on Y)

# %%
# fitted_values =  lin_reg_1.predict()
# residuals  = lin_reg_1.resid
# fig, ax = plt.subplots(1,2,figsize=(12,5))
# sns.regplot(x=fitted_values, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
# ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
# ax[0].set(xlabel='Predicted', ylabel='Observed')

# sns.regplot(x=fitted_values, y=residuals, lowess=True, ax=ax[1], line_kws={'color': 'red'})
# ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
# ax[1].set(xlabel='Predicted', ylabel='Residuals')

# %%
df_data = pd.read_csv('DATA MA - EXPENDITURE_BY_AREA_DATA.csv')

# %%
df_data
# Out:
#      Year   COMPANY                                     CSR Project(s)  \
# 0    2021      MSIL  Improvement In Licensing System: Setting Of Au...
# 1    2021      MSIL  Setting Up Of Traffic Safety Management System...
# 2    2021      MSIL                                   Covid-19 Support
# 3    2021      MSIL  Running Dispensary, Anemia Reduction, Setting ...
# 4    2021      MSIL  Japan India Institute For Manufacturing(Jim) U...
# ..    ...       ...                                                ...
# 408  2015  MAHINDRA                                  Rural Development
# 409  2015  MAHINDRA  Health Eradicating Hunger Poverty And Malnutri...
# 410  2015  MAHINDRA  Health Eradicating Hunger Poverty And Malnutri...
# 411  2015  MAHINDRA               Prime Ministers National Relief Fund
# 412  2015  MAHINDRA                                  Rural Development
#
#                      Development Sector(s)  \
# 0          Livelihood Enhancement Projects
# ...

# %%
df.head()
# Out:
#   Company Name  NUM_OF_CSR_SUSTAIN_CMTE_MTGS  SIZE_OF_CSR_SUSTAIN_COMMTTEE  \
# 0         MSIL                           2.0                           3.0
# 1         MSIL                           2.0                           3.0
# 2         MSIL                           1.0                           3.0
# 3         MSIL                           3.0                           3.0
# 4         MSIL                           2.0                           3.0
#
#    TOBIN_Q_RATIO  RETURN_ON_ASSET  RETURN_COM_EQY  ARDR_LIQUIDITY_RATIO  \
# 0         3.3184           5.3132          7.1953                   NaN
# 1         3.1674           6.5022          8.6134                   NaN
# 2         2.2593           8.8968         11.7631                   NaN
# 3         3.4148          12.3157         17.0641                   NaN
# 4         4.7365          14.0452         19.7904                   NaN
#
#    ESG_DISCLOSURE_SCORE  GOVNCE_DISCLOSURE_SCORE  ENVIRON_DISCLOSURE_SCORE  \
# ...

# %%
new_data = pd.merge(df_data,df,left_on = ['Year','COMPANY'],right_on=['Year','Company Name'])

# %%
new_data.head()
# Out:
#    Year COMPANY                                     CSR Project(s)  \
# 0  2021    MSIL  Improvement In Licensing System: Setting Of Au...
# 1  2021    MSIL  Setting Up Of Traffic Safety Management System...
# 2  2021    MSIL                                   Covid-19 Support
# 3  2021    MSIL  Running Dispensary, Anemia Reduction, Setting ...
# 4  2021    MSIL  Japan India Institute For Manufacturing(Jim) U...
#
#              Development Sector(s)    State            District  \
# 0  Livelihood Enhancement Projects    Delhi           New Delhi
# 1                        Education  Gujarat  Nec/ Not Mentioned
# 2                      Health Care  Gujarat  Nec/ Not Mentioned
# 3                      Health Care  Gujarat  Nec/ Not Mentioned
# 4                Vocational Skills  Gujarat  Nec/ Not Mentioned
#
#    Project Amount Outlay (INR Cr.)  Amount Spent (INR Cr.)  \
# 0                             7.48                    7.48
# ...

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ab = new_data[new_data['COMPANY']=='MSIL'].groupby(['Development Sector(s)']).agg({'Amount Spent (INR Cr.)':'mean'}).reset_index()

# %%
ab = new_data[new_data['COMPANY']=='MAHINDRA'].groupby(['Development Sector(s)']).agg({'Amount Spent (INR Cr.)':'mean'}).reset_index()

# %%
import squarify
plt.figure(figsize=(12,8))
sns.set_style(style="whitegrid") # set seaborn plot style
sizes= ab["Amount Spent (INR Cr.)"].values# proportions of the categories
label=ab["Development Sector(s)"]
colors=['#3C6255','#61876E','#A6BB8D','#EAE7B1'] #color palette

squarify.plot(sizes=sizes, label=label, pad= True,alpha=0.8,color=colors)
plt.title('Distibution of CSR Amount into different sectors by MAHINDRA group')
plt.text(50, 100, "Title",                    #sets position to place text using data coordinates
         fontsize = 2, 
         color='white', 
         horizontalalignment='center',#within the text box, aligns horizontally
         verticalalignment='bottom',  #within the text box, aligns towards top? I have no explanation for why syntax seems backward.
         zorder = 20) 
   
plt.show()

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
plt.figure(figsize=(12,8))
text = 'What really matters is how we accelerate India’s access to affordable, cleaner energy,” said Bill Davis, Lead Country Manager, South Asia, ExxonMobilRead more at://economictimes.indiatimes.ccleshow/71589531.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst'
wordcloud = WordCloud(width= 800,height=500,margin=0).generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.margins(x=5,y=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-a9a00c1fa967> in <module>
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 from wordcloud import WordCloud, STOPWORDS
#       6 plt.figure(figsize=(12,8))
#       7 text = 'What really matters is how we accelerate India’s access to affordable, cleaner energy,” said Bill Davis, Lead Country Manager, South Asia, ExxonMobilRead more at://economictimes.indiatimes.ccleshow/71589531.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst'
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
a =  new_data.groupby(['Year','COMPANY']).agg({'CSR Project(s)':'count','ESG_SCORE':np.mean})
a = a.reset_index()
a

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

fig.suptitle('Distibution of average of Financial Parameters of companies which are GRI compiant Vs which are not over time')
sns.set_style("whitegrid")
palette = sns.color_palette("mako_r", 6)

sns.regplot(ax=axes[1, 0],data=a[a['COMPANY']=='MAHINDRA'], x='ESG_SCORE', y='CSR Project(s)')
# sns.regplot(ax=axes[1, 1],data=a[a['COMPANY']=='MSIL'], x='ESG_SCORE', y='CSR Project(s)')
# sns.regplot(ax=axes[1, 2],data=a[a['COMPANY']=='TATA'], x='ESG_SCORE', y='CSR Project(s)')

# sns.lineplot(ax=axes[0, 1], data=a, x='Year', y='EBITDA',hue='GRI_COMPLIANCE',palette = "mako_r")
# sns.lineplot(ax=axes[1, 0], data=a, x='Year', y='NET_INCOME',hue='GRI_COMPLIANCE',palette = "mako_r")
# sns.lineplot(ax=axes[1, 1], data=a, x='Year', y='RETURN_ON_ASSET',hue='GRI_COMPLIANCE',palette = "mako_r")

plt.show()

# %%
sns.lineplot(data=a, x='Year', y='CSR Project(s)', hue='COMPANY', palette = "mako_r")
sns.lineplot(data=a, x='Year', y='ESG_SCORE', hue='COMPANY')
